# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

train = pd.read_csv('F:/Class 09/week4/Tool/python-and-data-science-tools-main/week4/recipes.csv')
train
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0             0        True        True       True        False          1.0
# 1             1        True        True      False        False          0.0
# 2             2       False       False      False        False          3.0
# 3             3        True       False       True        False          2.0
# 4             4       False        True      False        False         31.0
# ..          ...         ...         ...        ...          ...          ...
# 145         145       False        True       True        False         18.0
# 146         146        True       False      False        False          1.0
# 147         147        True        True       True         True         93.0
# 148         148        True        True      False        False          5.0
# 149         149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# ...

# %%
# 1 Print the names of Columns that have null values

def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
#         mz_table.to_excel('D:/sampledata/missing_and_zero_values.xlsx', freeze_panes=(1,0), index = False)
        return mz_table

missing_zero_values_table(train)
# Out:
# Your selected dataframe has 79 columns and 150 Rows.
# There are 48 columns that have missing values.
#                               Zero Values  Missing Values  % of Total Values  \
# CaffeinepercentOfDailyNeed              0             141               94.0
# CaffeineAmount                          0             141               94.0
# AlcoholpercentOfDailyNeed               0             129               86.0
# AlcoholAmount                           0             129               86.0
# VitaminDAmount                          0              75               50.0
# VitaminDpercentOfDailyNeed              0              75               50.0
# VitaminB12percentOfDailyNeed            0              57               38.0
# VitaminB12Amount                        0              57               38.0
# VitaminCAmount                          0              31               20.7
# VitaminCpercentOfDailyNeed              0              31               20.7
# ...

# %%
# 2 Print the recipes with the highest number of aggregateLikes
column = train["aggregateLikes"]
maxValue = column.max()
maxIndex = train['aggregateLikes'].argmax()
string_print = f"In feature aggregateLikes in index {maxIndex} the maximum value is {maxValue}."
print(string_print)
# Out:
# In feature aggregateLikes in index 50 the maximum value is 16911.

# %%
#3 Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.
train2 = train.copy()
train2['CalciumpercentOfDailyNeed'].replace(np.NaN, train2['CalciumpercentOfDailyNeed'].mean()).head(5)
# Out:
# 0     1.81000
# 1    12.25669
# 2    10.08000
# 3     2.68000
# 4    16.28000
# Name: CalciumpercentOfDailyNeed, dtype: float64

# %%
# 4 Delete the columns that have null values == 141
train3 = train.copy()
train3.drop('CaffeinepercentOfDailyNeed',axis='columns', inplace=True)
train3.drop('CaffeineAmount',axis = 'columns',inplace = True)

# %%
# 5 Print the title of the recipes that are vegetarian == TRUE and glutenFree == True
for index, row in train.iterrows():
    if row['vegetarian'] == True and row['glutenFree'] == True:
#        print(index)
        print(row['title'])
# Out:
# Banana Blueberry Pancakes
# Basil and Orange Confit Compound Butter
# Spicy Carrot Amaranth Soup
# Nutty Rice
# Fire Roasted Tomato Chutney
# Butternut Squash Soup
# Green Beans with Garlic Chips
# Easy Eggplant Parmesan
# Kappa Maki
# Vegan Chana Masala Curry
# Grilled Peach Melba with Vanilla Bean Frozen Yogurt
# Detox Orange Carrot Juice
# Roasted Asparagus with Egg Salad
# Three Ingredient Frozen Pina Colada
# Peach Coconut Ice Cream
# Sautéed Balsamic Green Beans With Cherry Tomatoes
# Ginger Melon Side Salad
# Chicken with Avocado Peach Salsa
# EASY, CUMIN-LENTIL SPREAD
# Luscious Palak Paneer
# Beet Slaw
# Roasted Strawberry Coconut Milk Ice Cream
# Breakfast Porridge
# Peanut Butter Cookies with Flax Seeds and Chocolate
# Blender Carrot Soup
# Dandelion pesto
# Coconut Flour Muffins
# Japanese Cucumber Salad
# Blueberry Mojito Popsicles
# Fried Brown Rice
# Seasonal Autumn Stew
# Slow Cooker Healthy Sweet Potato Soup with Coconut and Pistachios
# ...

# %%
# 6 .How many vegan recipes are there (Vegan = Vegetarian and dairy free)?
x = 0
for index, row in train.iterrows():
    if row['vegetarian'] == True and row['dairyFree'] == True:
        x = x + 1
string_print = f"Total people which Vegetarian and dairy free are  = {x}."        
print(string_print)
# Out:
# Total people which Vegetarian and dairy free are  = 29.

# %%
# 7 .Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?
# I suppose Vegan equal to Vegetarian and dairy free as per previous excersise
x = 0
y = 0
for index, row in train.iterrows():
    if row['vegetarian'] == True and row['dairyFree'] == True:
        s = row['VitaminB12Amount']
        if pd.isna(s) == False:
            x = x + float(row['VitaminB12Amount'])
            y = y + 1
c = x/y            
VitaminB12Amount_vegetarian = f"Average VitaminB12Amount for Vegetarian  = {c}."
total_vegetarian_b12 = f"total_vegetarian_VitaminB12Amount  = {y}." 

print(VitaminB12Amount_vegetarian) 
print(total_vegetarian_b12)


x = 0
y = 0
for index, row in train.iterrows():
    if row['vegetarian'] == False or row['dairyFree'] == False:
        s = row['VitaminB12Amount']
        if pd.isna(s) == False:
            x = x + float(row['VitaminB12Amount'])
            y = y + 1
c = x/y            
VitaminB12Amount_Non_vegetarian = f"Average VitaminB12Amount for Non Vegetarian  = {c}."
total_Non_vegetarian_b12 = f"total_vegetarian_VitaminB12Amount  = {y}." 

print(VitaminB12Amount_Non_vegetarian)
print(total_Non_vegetarian_b12)
# Out:
# Average VitaminB12Amount for Vegetarian  = 0.24333333333333332.
# total_vegetarian_VitaminB12Amount  = 3.
# Average VitaminB12Amount for Non Vegetarian  = 1.0345555555555552.
# total_vegetarian_VitaminB12Amount  = 90.

# %%
#8 . Compare the average health Score for both types of recipes (vegan vs non-vegan).
# I suppose Vegan equal to Vegetarian and dairy free as per  excersise 6.
x = 0
y = 0
for index, row in train.iterrows():
    if row['vegetarian'] == True and row['dairyFree'] == True:
        s = row['healthScore']
        if pd.isna(s) == False:
            x = x + float(row['healthScore'])
            y = y + 1
c = x/y            
healthScore_vegetarian = f"Average healthScore for Vegan  = {c}."
total_vegetarian_b12 = f"total_Vegan_healthScore  = {x}." 
 
print(healthScore_vegetarian)
print(total_vegetarian_b12)

x = 0
y = 0
for index, row in train.iterrows():
    if row['vegetarian'] == False or row['dairyFree'] == False:
        s = row['healthScore']
        if pd.isna(s) == False:
            x = x + float(row['healthScore'])
            y = y + 1
c = x/y            
Non_healthScore_vegetarian = f"Average healthScore for Non Vegan  = {c}."
total_Non_vegetarian_b12 = f"total_vegetarian_healthScore  = {x}." 
print(Non_healthScore_vegetarian)
print(total_Non_vegetarian_b12)
# Out:
# Average healthScore for Vegan  = 27.724137931034484.
# total_Vegan_healthScore  = 804.0.
# Average healthScore for Non Vegan  = 18.785123966942148.
# total_vegetarian_healthScore  = 2273.0.

# %%
# 9 Create a new column: "VeganWeek" where you decrease the price of vegan products by 10%, but only if they already cost more than 100.

list = []
#for index, row in train.iterrows():   
for index, row in dfx.iterrows():
    b = 0
    a = 0
    if row['vegetarian'] == True and row['dairyFree'] == True:
        a = float(row['pricePerServing'])
        if a > 100:
            b = a - a * 0.1
        else:
            b = a
    else:
        b = float(row['pricePerServing'])           
    list.append(b)
    
train['VeganWeek'] = list

# %%
#10 Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?
b = 0
for index, row in train.iterrows():
     if row['vegetarian'] == False or row['dairyFree'] == False:
        a = float(row['readyInMinutes'])
        if b<a:
            b = a  
s = np.divmod(b,60)
time_string = f"The require time is {s[0]} hour and {s[1]} minute."
print(time_string)
# Out:
# The require time is 5.0 hour and 28.0 minute.

# %%
# 10_v1 Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
 
from sklearn import linear_model


# In[2]:


df = pd.read_csv('F:/Class 09/week4/Tool/python-and-data-science-tools-main/week4/recipes.csv')


# In[3]:


X = df[['CaloriesAmount', 'FatAmount']]
y = df['healthScore']


# In[4]:


regr = linear_model.LinearRegression()
regr.fit(X, y)


# In[5]:


from sklearn.linear_model import LinearRegression
X = df['CaloriesAmount'].values[:,np.newaxis]
# target data is array of shape (n,) 
y = df['FatAmount'].values
model2 = LinearRegression()
model2.fit(X, y)
plt.scatter(X, y,color='g')
plt.plot(X, model2.predict(X),color='k')

plt.show()

# %%
# 10_v2 Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?

import pandas as pd
from sklearn import linear_model
import tkinter as tk 
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
df = pd.read_csv('F:/Class 09/week4/Tool/python-and-data-science-tools-main/week4/recipes.csv')


# In[2]:


X = df[['CaloriesAmount', 'FatAmount']].astype(float)
y = df['healthScore'].astype(float)


# In[3]:


# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# tkinter GUI
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)


# In[4]:


import pandas as pd
from sklearn import linear_model
import tkinter as tk 
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

X = df[['CaloriesAmount', 'FatAmount']].astype(float)
Y = df['healthScore'].astype(float)




# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# tkinter GUI
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)
# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)
# New_Interest_Rate label and input box
label1 = tk.Label(root, text='CaloriesAmount ')
canvas1.create_window(100, 100, window=label1)
entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)
# New_Unemployment_Rate label and input box
label2 = tk.Label(root, text=' FatAmount: ')
canvas1.create_window(120, 120, window=label2)
entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

def values(): 
   global CaloriesAmount #our 1st input variable
   CaloriesAmount = float(entry1.get()) 
   
   global FatAmount #our 2nd input variable
   FatAmount = float(entry2.get()) 
   
   Prediction_result  = ('Predicted healthScore: ', regr.predict([[CaloriesAmount ,FatAmount]]))
   label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
   canvas1.create_window(260, 280, window=label_Prediction)
   
button1 = tk.Button (root, text='Predicted healthScore',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(270, 150, window=button1)

#plot 1st scatter 
figure3 = plt.Figure(figsize=(5,4), dpi=100)
ax3 = figure3.add_subplot(111)
ax3.scatter(df['CaloriesAmount'].astype(float),df['healthScore'].astype(float), color = 'r')
scatter3 = FigureCanvasTkAgg(figure3, root) 
scatter3.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax3.legend(['healthScore']) 
ax3.set_xlabel('CaloriesAmount')
ax3.set_title('CaloriesAmount Vs. healthScore')



#plot 2nd scatter 
figure4 = plt.Figure(figsize=(5,4), dpi=100)
ax4 = figure4.add_subplot(111)
ax4.scatter(df['FatAmount'].astype(float),df['healthScore'].astype(float), color = 'g')
scatter4 = FigureCanvasTkAgg(figure4, root) 
scatter4.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax4.legend(['healthScore']) 
ax4.set_xlabel('FatAmount')
ax4.set_title('FatAmount Vs. healthScore')

root.mainloop()
# Out:
# Intercept:
#  10.193675275720942
# Coefficients:
#  [ 0.06616478 -0.70126737]
# Intercept:
#  10.193675275720942
# Coefficients:
#  [ 0.06616478 -0.70126737]
